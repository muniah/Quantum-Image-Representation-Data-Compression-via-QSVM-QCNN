# %% [markdown]
# # Overview
#
# - We'll use classical and quantum methods for our data compression and prediction methods.
#
# - We organize the methods below:
#
# (i) Avi code: CNN, QCNN, QHED
#
# (ii) Munia code: SVM, QSVM, INEQR

# %%
# Import libraries
import numpy as np
import import_ipynb

# %% [markdown]
# # Importing modules
#
# - We have organized the code for each component (refer to slides/paper) into modules.
#
# - Here, we can call the modules to present their final result. We give an example with INEQR. Import the file name and call a 'final results' variable.
#
# - To see the underlying code, please check the other files under this directory.

# %%
from INEQR import *

# %% [markdown]
# # Example: INEQR

# %%
from INEQR import *

embedding.draw("mpl", style="iqp", scale = 0.25)
